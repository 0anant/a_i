# %% [markdown]
# Load ENV variables

# %%
import sys
print(sys.executable)
# Out:
# /Users/nisha/Desktop/a_i/env/bin/python

# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4")

# %%
res = llm.invoke("Who is PM of India?")
print(res.content)
